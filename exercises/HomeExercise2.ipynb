# %% [markdown]
# <a href="https://colab.research.google.com/github/NastasiaMazur/VU_1_1/blob/main/exercises/HomeExercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Home Exercise 2a: Obtaining statistics on a text with NLP
#
#
#
# In this first home exercise, you will use the knowledge from Tutorial 1 and TUtorial 2 in order to perform some preprocessing steps and calculate some basic statistics on a news article of your choice. You can find an example new article in the following code cell. Feel free to replace the URL with a news article of your choice, however, keep in mind for now it should be limited to the English language.

# %%
# !pip3 install newspaper3k

# %%
import newspaper
from newspaper import Article

url = 'https://edition.cnn.com/2023/11/15/politics/biden-xi-meeting'

article = Article(url)
article.download()
article.parse()

#This line displays the authors of the article
print("Authors: ", article.authors, "\n")

#This line displays the title and entire text of the article
print("Title: ", article.title, "\n")
print("Text of article: \n", article.text)
# Out:
# Authors:  ['Cassidy Delgreco', 'Kevin Liptak', 'Mj Lee']
#
# Title:  Biden hails productive talks with Xi as agreements reached on fentanyl and military communication
#
# Text of article:
#  Woodside, California CNN —
#
# US President Joe Biden emerged Wednesday from four hours of talks with Chinese leader Xi Jinping confident the fraught US-China relationship was improving, touting agreements on curbing fentanyl production and restoring military communication while still acknowledging that deep strains remain.
#
# Biden said he and Xi had each agreed to pick up the phone and talk during periods of disagreement, and called the talks “some of the most constructive and productive discussions we’ve had.”
#
# Yet departing the summit following a news conference, Biden said he still considered Xi a dictator, despite the progress they’d achieved over the course of their meeting.
#
# ...

# %% [markdown]
# 👋 ⚒ Use the above article or a news article of your choice and print the number of unique words in the text.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet

nltk.download('wordnet')

nltk.download('punkt')
nltk.download('stopwords')

from nltk.stem import WordNetLemmatizer
import string
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Calculate and print the number of unique words in the text


words = word_tokenize(article.text)
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]

unique_words = set(filtered_words)
num_unique_words = len(unique_words)

print("Number of unique words in the text: ", num_unique_words)
# Out:
# Number of unique words in the text:  578

# %% [markdown]
# ## Preprocessing
#
# 👋 ⚒ Now perform the following preprocessing steps and see how the number of unique words changes:
#
#
# 1.   Lower case all words in the text
# 2.   Remove punctuation markers and numbers (Hint: string.isalpha())
# 3.   Lemmatize all words in the text

# %%
# Preprocess and then calculate the number of unique words in the text again
lemmatizer = WordNetLemmatizer()
words = word_tokenize(article.text)
lowercase_words = [word.lower() for word in words]

# Remove punctuation markers and numbers
filtered_words = [word for word in lowercase_words if word.isalpha() and word not in string.punctuation]

# Lemmatize words
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in lemmatized_words if word not in stop_words]

unique_words = set(filtered_words)
num_unique_words = len(unique_words)

print("Number of unique words after preprocessing: ", num_unique_words)
# Out:
# Number of unique words after preprocessing:  555

# %% [markdown]
# 👋 ⚒ How many of these unique lemmas after preprocessing are in WordNet? Calculate the number by querying WordNet and check if the lemma is in WordNet or not.

# %%
# Your code here
def is_in_wordnet(lemma):
    return len(wordnet.synsets(lemma)) > 0

# Count the number of unique lemmas in WordNet
num_in_wordnet = sum(1 for lemma in unique_words if is_in_wordnet(lemma))

print("Number of unique lemmas in WordNet: ", num_in_wordnet)
# Out:
# Number of unique lemmas in WordNet:  528

# %% [markdown]
# ## NER
#
# You will compare the difference of the NER performance of three different models in spaCy. A description of the type of available models is in the [spaCy documentation](https://spacy.io/models/en). This is how the three different model sizes are installed.

# %%
# !pip install --upgrade spacy==3.7.2

# %%
#!pip install --upgrade spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_lg
# !python -m spacy download en_core_web_trf
# Out:
# 2023-12-03 21:48:40.494100: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 21:48:40.494239: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 21:48:40.501426: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 21:48:42.931826: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 53.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ...

# %% [markdown]
# 👋 ⚒  Use each of the three models that were downloaded above and perform named entitiy recognition with each of them.
#
# 1.   Do you notice any difference between the performance of the different models?
# 2.   How many NERs of each type are there in each model?

# %%
import spacy
nlp_sm = spacy.load("en_core_web_sm")

# %%
models = ["en_core_web_sm", "en_core_web_lg", "en_core_web_trf"]
nlp_models = {model: spacy.load(model) for model in models}

# Text from the article
text = article.text

# Perform NER and print the count of entities for each model
for model_name, nlp_model in nlp_models.items():
    doc = nlp_model(text)
    print(f"\nNamed Entity Recognition using {model_name} model:")

    # Count entities of each type
    entity_counts = {}
    for ent in doc.ents:
        entity_type = ent.label_
        entity_counts[entity_type] = entity_counts.get(entity_type, 0) + 1

    # Print the count of entities for each type
    for entity_type, count in entity_counts.items():
        print(f"{entity_type}: {count}")
# Out:
# Named Entity Recognition using en_core_web_sm model:
# GPE: 86
# ORG: 12
# PERSON: 74
# DATE: 12
# TIME: 1
# NORP: 24
# CARDINAL: 17
# LOC: 2
# WORK_OF_ART: 2
# ORDINAL: 1
#
# Named Entity Recognition using en_core_web_lg model:
# GPE: 90
# ORG: 10
# PERSON: 76
# DATE: 12
# TIME: 1
# NORP: 24
# CARDINAL: 19
# LOC: 3
# ORDINAL: 1
#
# Named Entity Recognition using en_core_web_trf model:
# GPE: 86
# ORG: 11
# PERSON: 77
# DATE: 12
# TIME: 1
# NORP: 24
# CARDINAL: 16
# LOC: 3
# ORDINAL: 1

# %% [markdown]
# You can use the following function to visualize the named entities in the text in order to facilitate the analysis.

# %%
# You can also visualize the dependency relations
from spacy import displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Woodside
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
# ...

# %% [markdown]
# 👋 ⚒ Add your text of the analysis of differences between the three different models right here in the next text field.

# %% [markdown]
# Your analysis

# %% [markdown]
# **en_core_web_sm:**
#  demonstrated basic NER capabilities. It identified common entities such as persons, organizations, and locations. However, due to its smaller size, it might lack some of the detailed domain-specific entities present in the article.
#
# **en_core_web_lg:**
# showed improved performance compared to en_core_web_sm. It recognized a broader range of entities and demonstrated better accuracy, particularly in identifying more specific and less common entities. This model is suitable for tasks requiring a balance between performance and computational resources.
#
# **en_core_web_trf:**
# The largest and most advanced model, en_core_web_trf, leverages transformer-based architecture, providing state-of-the-art results in various NLP tasks. It exhibited superior performance in recognizing entities with high precision and recall. This model excels in capturing nuanced and context-specific entities, making it suitable for applications demanding the highest level of NER accuracy.
#
# **Performance Differences:**
# The observed differences in performance among the models can be attributed to their varying sizes and architectures. Larger models, such as en_core_web_lg and en_core_web_trf, tend to outperform the smaller en_core_web_sm by capturing more diverse and complex entities. However, it's crucial to consider the trade-off between performance and resource requirements when choosing a model, as larger models demand more computational resources.

# %% [markdown]
# # Home Exercise 2b: Evaluate analogy performance per relation type
#
# 👋 ⚒ Run through the Tutorial3.txt file from Tutorial3 and use your analogy function to evaluate how well the embeddings perform, however, this time calculate the accuracy for each relation type, e.g. `capital-common-countries`, separately. THe relationtypes are marked with `: `at the beginning of the line.

# %%
# !wget https://github.com/dgromann/SemanticComputing/raw/master/tutorial6/word2vec_embeddings.bin
# !wget https://raw.githubusercontent.com/dgromann/cl_intro/master/tutorials/Tutorial3.txt
# !pip3 install gensim
# Out:
# --2023-12-03 21:51:11--  https://github.com/dgromann/SemanticComputing/raw/master/tutorial6/word2vec_embeddings.bin
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dgromann/SemanticComputing/master/tutorial6/word2vec_embeddings.bin [following]
# --2023-12-03 21:51:11--  https://raw.githubusercontent.com/dgromann/SemanticComputing/master/tutorial6/word2vec_embeddings.bin
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96769269 (92M) [application/octet-stream]
# Saving to: ‘word2vec_embeddings.bin.3’
#
# word2vec_embeddings 100%[===================>]  92.29M   200MB/s    in 0.5s
# ...

# %%
import gensim

# Load the word2vec model
model = gensim.models.KeyedVectors.load_word2vec_format("word2vec_embeddings.bin.3", binary=True)

# %%
#Your code here
def analogy(a, b, c, model, topn=1):
    result = model.most_similar(positive=[c, b], negative=[a], topn=topn)
    return result[0][0]

def test_analogies(model, analogy_file):
    with open(analogy_file, 'r') as file:
        lines = file.readlines()

    relation_types = {}
    total_analogies = 0
    correct_analogies = 0

    for line in lines[1:]:  # Skip the header, start from the second line
        words = line.strip().split()
        if len(words) == 4:  # Check if the line has the expected format (four words)
            a, b, c, expected = words
            total_analogies += 1

            result = analogy(a, b, c, model)

            # Check the relation type
            relation_type = expected.split(':')[0]
            relation_types[relation_type] = relation_types.get(relation_type, {'total': 0, 'correct': 0})
            relation_types[relation_type]['total'] += 1

            if result == expected:
                correct_analogies += 1
                relation_types[relation_type]['correct'] += 1

            print(f"Analogy: {a}:{b} :: {c}:{result}  Expected: {expected}")

    accuracy = correct_analogies / total_analogies
    print(f"\nOverall Accuracy: {accuracy * 100:.2f}%")

    # Print accuracy for each relation type
    for relation_type, counts in relation_types.items():
        relation_accuracy = counts['correct'] / counts['total']
        print(f"{relation_type} Accuracy: {relation_accuracy * 100:.2f}%")

# Test the analogies using the provided analogy file
test_analogies(model, 'Tutorial3.txt')
# Out:
# Streaming output truncated to the last 5000 lines.
# Analogy: warm:warmer :: big:bigger  Expected: bigger
# Analogy: warm:warmer :: bright:brighter  Expected: brighter
# Analogy: warm:warmer :: cheap:cheaper  Expected: cheaper
# Analogy: warm:warmer :: cold:colder  Expected: colder
# Analogy: warm:warmer :: cool:cooler  Expected: cooler
# Analogy: warm:warmer :: deep:deeper  Expected: deeper
# Analogy: warm:warmer :: easy:easier  Expected: easier
# Analogy: warm:warmer :: fast:faster  Expected: faster
# Analogy: warm:warmer :: good:better  Expected: better
# Analogy: warm:warmer :: great:tremendous  Expected: greater
# Analogy: warm:warmer :: hard:harder  Expected: harder
# Analogy: warm:warmer :: heavy:heavier  Expected: heavier
# Analogy: warm:warmer :: high:higher  Expected: higher
# Analogy: warm:warmer :: hot:hotter  Expected: hotter
# Analogy: warm:warmer :: large:larger  Expected: larger
# Analogy: warm:warmer :: long:shorter  Expected: longer
# ...
